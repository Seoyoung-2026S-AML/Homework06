# %% [markdown]
# # Homework06
#
# Exercises to practice pandas, data analysis and regression
#
# ## Goals
#
# - Understand the effects of pre-processing data
# - Get familiar with the ML flow: encode -> normalize -> train -> evaluate
# - Understand the difference between regression and classification tasks
# - Build intuition for different regression models

# %% [markdown]
# ### Setup
#
# Run the following 2 cells to import all necessary libraries and helpers for this homework.

# %%
# !wget -q https://github.com/PSAM-5020-2026S-A/5020-utils/raw/main/src/data_utils.py

# %%
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.preprocessing import OrdinalEncoder, StandardScaler
from sklearn.linear_model import LinearRegression, SGDRegressor

from data_utils import object_from_json_url
from data_utils import regression_error

# %% [markdown]
# ### Load Dataset
#
# Let's load up the full [ANSUR](https://www.openlab.psu.edu/ansur2/) dataset that we looked at briefly in [Week 02](https://github.com/DM-GY-9103-2024F-H/WK02).
#
# This is the dataset that has anthropometric information about U.S. Army personnel.
#
# #### WARNING
#
# Like we mentioned in class, this dataset is being used for these exercises due to the level of detail in the dataset and the rigorous process that was used in collecting the data.
#
# This is a very specific dataset and should not be used to draw general conclusions about people, bodies, or anything else that is not related to the distribution of physical features of U.S. Army personnel.

# %%
# Load Dataset
ANSUR_FILE = "https://raw.githubusercontent.com/PSAM-5020-2026S-A/5020-utils/main/datasets/json/ansur.json"
ansur_data = object_from_json_url(ANSUR_FILE)

# Look at first 2 records
ansur_data[:2]
# Out:
# [{'age': 18,
#   'gender': 'F',
#   'height': 66,
#   'weight': 135,
#   'span': 1699,
#   'stature': 1645,
#   'ear': {'breadth': 30, 'length': 61, 'protrusion': 20},
#   'foot': {'breadth': 97, 'length': 243},
#   'hand': {'breadth': 78, 'length': 182, 'palm': 108},
#   'head': {'height': 243, 'circumference': 557}},
#  {'age': 30,
#   'gender': 'M',
#   'height': 68,
#   'weight': 207,
#   'span': 1749,
#   'stature': 1715,
#   'ear': {'breadth': 35, 'length': 63, 'protrusion': 17},
#   'foot': {'breadth': 100, 'length': 252},
#   'hand': {'breadth': 87, 'length': 184, 'palm': 114},
#   'head': {'height': 238, 'circumference': 560}}]

# %% [markdown]
# #### Nested data
#
# This is that *nested* dataset from Week 02.
#
# # 🤔
#
# Let's load it into a `DataFrame` to see what happens.

# %%
# Read into DataFrame
ansur_df = pd.DataFrame.from_records(ansur_data)
ansur_df.head()
# Out:
#    age gender  height  weight  span  stature  \
# 0   18      F      66     135  1699     1645
# 1   30      M      68     207  1749     1715
# 2   27      M      67     121  1684     1657
# 3   20      M      73     185  1878     1828
# 4   33      M      76     150  1977     1883
#
#                                                ear  \
# 0  {'breadth': 30, 'length': 61, 'protrusion': 20}
# 1  {'breadth': 35, 'length': 63, 'protrusion': 17}
# 2  {'breadth': 36, 'length': 59, 'protrusion': 24}
# 3  {'breadth': 36, 'length': 60, 'protrusion': 21}
# 4  {'breadth': 39, 'length': 65, 'protrusion': 27}
#
#                               foot  \
# 0   {'breadth': 97, 'length': 243}
# 1  {'breadth': 100, 'length': 252}
# 2   {'breadth': 92, 'length': 251}
# 3  {'breadth': 104, 'length': 280}
# 4  {'breadth': 101, 'length': 271}
#
#                                           hand  \
# 0  {'breadth': 78, 'length': 182, 'palm': 108}
# 1  {'breadth': 87, 'length': 184, 'palm': 114}
# 2  {'breadth': 84, 'length': 180, 'palm': 103}
# 3  {'breadth': 95, 'length': 201, 'palm': 124}
# 4  {'breadth': 90, 'length': 194, 'palm': 113}
#
#                                     head
# 0  {'height': 243, 'circumference': 557}
# 1  {'height': 238, 'circumference': 560}
# 2  {'height': 239, 'circumference': 516}
# 3  {'height': 270, 'circumference': 582}
# 4  {'height': 254, 'circumference': 559}

# %% [markdown]
# # 😓🙄
#
# That didn't work too well. We ended up with objects in our columns.
#
# Luckily, our `DataFrame` library has a function called [`json_normalize()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.json_normalize.html) that can help.

# %%
# Read into DataFrame
ansur_df = pd.json_normalize(ansur_data)
ansur_df.head()
# Out:
#    age gender  height  weight  span  stature  ear.breadth  ear.length  \
# 0   18      F      66     135  1699     1645           30          61
# 1   30      M      68     207  1749     1715           35          63
# 2   27      M      67     121  1684     1657           36          59
# 3   20      M      73     185  1878     1828           36          60
# 4   33      M      76     150  1977     1883           39          65
#
#    ear.protrusion  foot.breadth  foot.length  hand.breadth  hand.length  \
# 0              20            97          243            78          182
# 1              17           100          252            87          184
# 2              24            92          251            84          180
# 3              21           104          280            95          201
# 4              27           101          271            90          194
#
#    hand.palm  head.height  head.circumference
# 0        108          243                 557
# 1        114          238                 560
# 2        103          239                 516
# 3        124          270                 582
# 4        113          254                 559

# %% [markdown]
# Much better. `DataFrames` are magic.
#
# #### Data Exploration
#
# Before we start creating models, let's do a little bit of data analysis and get a feeling for the shapes, distributions and relationships of our data.
#
# 1. Print `min`, `max` and `average` values for all of the features.
# 2. Print `covariance` tables for `age`, `ear.length` and `head.circumference`.
# 3. Plot `age`, `ear.length` and `head.circumference` versus the $1$ *feature* that is most correlated to each of them.
#
# Don't forget to *encode* and *normalize* the data.

# %%
# Work on Data Exploration here

### Encode non-numerical features

num = ansur_df.select_dtypes(include="number")

## 1. Print min, max, avg
for col in num.columns:
    print(f"{col}: min={num[col].min()}, max={num[col].max()}, avg={num[col].mean()}")

### Normalize all data

## 2. Print Covariances
for target in ["age", "ear.length", "head.circumference"]:
    print(f"\n-- Covariance with {target} --")
    print(num.cov()[target].sort_values(ascending=False))

## 3. Plot features most correlated to age, ear length and head circumference

corr = num.corr()
targets = ["age", "ear.length", "head.circumference"]

for t in targets:
    best_feat = corr[t].drop(t).abs().idxmax()
    best_val = corr[t][best_feat]

    print(f"{t} -> most correlated feature: {best_feat} (corr={best_val:.3f})")

    plt.figure()
    plt.scatter(num[best_feat], num[t])
    plt.xlabel(best_feat)
    plt.ylabel(t)
    plt.title(f"{t} vs {best_feat} (corr={best_val:.3f})")
    plt.show()
# Out:
# age: min=17, max=58, avg=29.74535714285714
# height: min=56, max=94, avg=68.24732142857142
# weight: min=0, max=321, avg=174.55839285714285
# span: min=1323, max=2121, avg=1763.703392857143
# stature: min=1409, max=1993, avg=1714.265357142857
# ear.breadth: min=25, max=46, avg=35.128928571428574
# ear.length: min=46, max=81, avg=62.637142857142855
# ear.protrusion: min=13, max=34, avg=22.266785714285714
# foot.breadth: min=77, max=126, avg=98.85089285714285
# foot.length: min=198, max=323, avg=262.9919642857143
# hand.breadth: min=67, max=105, avg=84.93696428571428
# hand.length: min=145, max=239, avg=189.26017857142858
# hand.palm: min=88, max=140, avg=113.91964285714286
# head.height: min=206, max=295, avg=249.17089285714286
# head.circumference: min=502, max=635, avg=570.0628571428572
#
# -- Covariance with age --
# age                   75.012481
# weight                63.419409
# span                  61.794434
# stature               29.626255
# ear.length            12.209246
# hand.length           10.419363
# hand.palm              7.458191
# hand.breadth           7.364371
# foot.length            7.341408
# ear.breadth            5.227157
# head.height            3.966725
# foot.breadth           3.740199
# head.circumference     2.230690
# height                 0.987441
# ear.protrusion        -0.253539
# Name: age, dtype: float64
#
# -- Covariance with ear.length --
# span                  215.065064
# stature               190.718915
# weight                 79.394294
# foot.length            35.205514
# head.circumference     25.129974
# ear.length             23.299281
# head.height            22.013083
# hand.length            18.600051
# hand.breadth           14.286107
# foot.breadth           13.991430
# age                    12.209246
# hand.palm              11.765621
# height                  7.879542
# ear.breadth             7.059829
# ear.protrusion          5.842491
# Name: ear.length, dtype: float64
#
# -- Covariance with head.circumference --
# span                  970.599644
# stature               765.061188
# head.circumference    336.458988
# weight                334.309599
# foot.length           160.058373
# head.height           118.836550
# hand.length            97.920596
# foot.breadth           60.036522
# hand.palm              59.052739
# hand.breadth           54.344738
# height                 31.172521
# ear.length             25.129974
# ear.breadth            13.035116
# ear.protrusion          7.240595
# age                     2.230690
# Name: head.circumference, dtype: float64
# age -> most correlated feature: ear.length (corr=0.292)
# ear.length -> most correlated feature: weight (corr=0.487)
# head.circumference -> most correlated feature: head.height (corr=0.546)

# %% [markdown]
# ### Interpretation
#
# <span style="color:hotpink;">
# Does anything stand out about these graphs? Or the correlations?<br>
# Are correlations symmetric? Does the feature most correlated to ear length also have ear length as its most correlated pair?
# </span>

# %% [markdown]
# <span style="color:hotpink;">
# What stands out: Age vs. ear length shows only a weak positive trend. Ear length vs. weight seems moderate. Head circumference vs. head height is the strongest and looks the most clearly linear.
#
# Correlations look symmetric.
#
# Correlations are symmetric in value, but most correlated partner is not guaranteed to be mutual.</span>

# %% [markdown]
# ### Regression
#
# Now, we want to create a regression model to predict `head.circumference` from the data.
#
# From our [Week 06](https://github.com/PSAM-5020-2026S-A/WK06) notebook, we can create a regression model by following these steps:
#
# 1. Load dataset (done! 🎉)
# 2. Encode label features as numbers (done! ⚡️)
# 3. Normalize the data (done! 🍾)
# 4. Separate the outcome variable and the input features
# 5. Create a regression model using all features
# 6. Run model on training data and measure error
# 7. Plot predictions and interpret results
# 8. Run model on test data, measure error, plot predictions, interpret results

# %%
# Work on Regression Model here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler, OrdinalEncoder
from sklearn.linear_model import LinearRegression

ansur_encoder = OrdinalEncoder()
ansur_encoded_df = ansur_df.copy()
ansur_encoded_df[["gender"]] = ansur_encoder.fit_transform(ansur_df[["gender"]])

ansur_scaler = StandardScaler()
ansur_scaled_df = pd.DataFrame(
    ansur_scaler.fit_transform(ansur_encoded_df),
    columns=ansur_encoded_df.columns)

## Separate outcome variable and input features
y = ansur_encoded_df["head.circumference"]
X = ansur_scaled_df.drop(columns=["head.circumference"])

model = LinearRegression().fit(X, y)

## Create a regression model
model = LinearRegression()
model.fit(X, y)


## Measure error on training data
y_pred = model.predict(X)
print("Average error (MAE):", np.mean(np.abs(y - y_pred)))


## Plot predictions and interpret results
plt.figure()
plt.scatter(y, y_pred, alpha=0.3)
plt.xlabel("Actual head.circumference")
plt.ylabel("Predicted head.circumference")
plt.title("Actual vs Predicted (Training)")
plt.show()
# Out:
# Average error (MAE): 10.891143745938628

# %%
## Load Test Data
ANSUR_TEST_FILE = "https://raw.githubusercontent.com/PSAM-5020-2026S-A/5020-utils/main/datasets/json/ansur-test.json"

ansur_test_data = object_from_json_url(ANSUR_TEST_FILE)
ansur_test_df = pd.json_normalize(ansur_test_data)

ansur_test_encoded_df = ansur_test_df.copy()

g_vals = ansur_encoder.transform(ansur_test_df[["gender"]])
ansur_test_encoded_df[["gender"]] = g_vals

ansur_test_scaled_df = ansur_scaler.transform(ansur_test_encoded_df)

# %%
## Run model on test data

## Measure error on test data

## Plot predictions and interpret results

# %% [markdown]
# ### Interpretation
#
# <span style="color:hotpink;">
# How well does your model perform?<br>
# How could you improve it?<br>
# Are there ranges of circumferences that don't get predicted well?
# </span>

# %% [markdown]
# <span style="color:hotpink;">EDIT THIS CELL WITH ANSWER</span>
